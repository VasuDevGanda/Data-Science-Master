# %% [markdown]
# ####  Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# When creating a custom exception, it is important to use the Exception class because it provides a standardized way of defining and handling errors in Python. The Exception class is the base class for all built-in exceptions in Python, and it provides a set of methods that can be used to customize the behavior of your custom exception.

# %% [markdown]
# #### Q2. Write a python program to print Python Exception Hierarchy.

# %%
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)

classtree(BaseException)
# Out:
#  BaseException
# ... Exception
# ...... TypeError
# ......... FloatOperation
# ......... MultipartConversionError
# ...... StopAsyncIteration
# ...... StopIteration
# ...... ImportError
# ......... ModuleNotFoundError
# ......... ZipImportError
# ...... OSError
# ......... ConnectionError
# ............ BrokenPipeError
# ............ ConnectionAbortedError
# ............ ConnectionRefusedError
# ............ ConnectionResetError
# ............... RemoteDisconnected
# ......... BlockingIOError
# ......... ChildProcessError
# ......... FileExistsError
# ......... FileNotFoundError
# ......... IsADirectoryError
# ......... NotADirectoryError
# ......... InterruptedError
# ............ InterruptedSystemCall
# ......... PermissionError
# ......... ProcessLookupError
# ......... TimeoutError
# ......... UnsupportedOperation
# ......... herror
# ......... gaierror
# ......... timeout
# ......... SSLError
# ............ SSLCertVerificationError
# ............ SSLZeroReturnError
# ...

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 15 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
# ...

# %% [markdown]
# ####  Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError Exception is the base class for all errors associated with arithmetic operation.
# * ZeroDivisionError
# * OverflowError
# * FloatingPointError

# %%
# ZeroDivisionError
try:
    1/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
# OverflowError
j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
        print(j)
except OverflowError as e:
    print(e)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# (34, 'Result too large')

# %% [markdown]
# #### Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError class is the Base class for errors raised when something can’t be found.

# %%
# Key Error
dic = {"a":"akki","b":"Lucky"}
try:
    dic["c"]
except KeyError as e:
    print(e)
# Out:
# 'c'

# %%
# Index Error
l = [1,2,3,4,5]
try :
    l[10]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# #### Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# * **ImportError** : This error generally occurs when a class cannot be imported due to one of the following reasons: The imported class is in a circular dependency. The imported class is unavailable or was not created. The imported class name is misspelled. The imported class from a module is misplaced.
#
# * **ModuleNotFoundError** : this error occurs when you're trying to access or use a module that cannot be found.

# %% [markdown]
# ####  Q6. List down some best practices for exception handling in python.

# %% [markdown]
# * Use always a specific Exception
# * Print always a specific message
# * Always try to logh
# * Always avoid to write multiple Exception Handling
# * Always try to prepare a proper documentation
# * Cleanup all the resources
